# %% [markdown]
# Direct Regression Nutrition Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd 'drive/MyDrive/CV_2024/FinalProject/nutri_estimate/nutri_estimate/final_model_combined'
# %pwd
# Out:
# /content/drive/MyDrive/CV_2024/FinalProject/nutri_estimate/nutri_estimate/final_model_combined
# '/content/drive/MyDrive/CV_2024/FinalProject/nutri_estimate/nutri_estimate/final_model_combined'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.models import efficientnet_v2_s
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
from PIL import Image
import os
import joblib

# GPU availability
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
transform = transforms.Compose([
    transforms.Resize((320, 320)),
    transforms.ToTensor()
])

# %%
scaler_directory = "./scalers"
scalers = {
    file.replace("_scaler.save", ""): joblib.load(os.path.join(scaler_directory, file))
    for file in os.listdir(scaler_directory)
    if file.endswith("_scaler.save")
}
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
class NutritionDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        image_path = os.path.join(self.root_dir, row['image_link'])
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        labels = {
            'protein': row['total_protein'],
            'fat': row['total_fat'],
            'carbs': row['total_carb'],
            'mass': row['total_mass']
        }
        return image, labels

# %%
df = pd.read_json('../preprocess/filtered_data.json', dtype={'total_mass': 'float64'})
X_test = df[df['split'] == 'test']
root_dir = '../preprocess'
test_dataset = NutritionDataset(X_test, root_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, drop_last=False)

# %%
class EfficientNetBase(nn.Module):
    def __init__(self):
        super(EfficientNetBase, self).__init__()
        self.base_model = efficientnet_v2_s(weights=None)
        self.base_model.classifier = nn.Identity()

    def forward(self, x):
        return self.base_model(x)

class MultiTaskModel(nn.Module):
    def __init__(self, base_model):
        super(MultiTaskModel, self).__init__()
        self.base_model = base_model
        in_features = 1280
        self.protein_branch = self._create_branch(in_features)
        self.fat_branch = self._create_branch(in_features)
        self.carbs_branch = self._create_branch(in_features)
        self.mass_branch = self._create_branch(in_features)

    def _create_branch(self, in_features):
        return nn.Sequential(
            nn.Linear(in_features, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        x = self.base_model(x)
        return {
            'protein': self.protein_branch(x),
            'fat': self.fat_branch(x),
            'carbs': self.carbs_branch(x),
            'mass': self.mass_branch(x)
        }

# %%
# Load the trained model
checkpoint_path = "./final_model/final_multi_task_model.pth"
base_model = EfficientNetBase()
model = MultiTaskModel(base_model)
state_dict = torch.load(checkpoint_path, map_location=device)
model.load_state_dict(state_dict)
model = model.to(device)
model.eval()
# Out:
# MultiTaskModel(
#   (base_model): EfficientNetBase(
#     (base_model): EfficientNet(
#       (features): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#           )
#           (1): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.005, mode=row)
#           )
#         )
#         (2): Sequential(
#           (0): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(24, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.01, mode=row)
#           )
#           (1): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.015000000000000003, mode=row)
#           )
#           (2): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.02, mode=row)
#           )
#           (3): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#           )
#         )
#         (3): Sequential(
#           (0): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.030000000000000006, mode=row)
#           )
#           (1): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.035, mode=row)
#           )
#           (2): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#           )
#           (3): FusedMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.045, mode=row)
#           )
#         )
#         (4): Sequential(
#           (0): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#           )
#           (1): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.05500000000000001, mode=row)
#           )
#           (2): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.06000000000000001, mode=row)
#           )
#           (3): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.065, mode=row)
#           )
#           (4): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.07, mode=row)
#           )
#           (5): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (1): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.075, mode=row)
#           )
#         )
#         (5): Sequential(
#           (0): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#           )
#           (1): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.085, mode=row)
#           )
#           (2): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.09, mode=row)
#           )
#           (3): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.095, mode=row)
#           )
#           (4): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#           )
#           (5): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.10500000000000001, mode=row)
#           )
#           (6): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.11000000000000001, mode=row)
#           )
#           (7): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.11500000000000002, mode=row)
#           )
#           (8): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.12000000000000002, mode=row)
#           )
#         )
#         (6): Sequential(
#           (0): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=960, bias=False)
#                 (1): BatchNorm2d(960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#           )
#           (1): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.13, mode=row)
#           )
#           (2): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.135, mode=row)
#           )
#           (3): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.14, mode=row)
#           )
#           (4): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.14500000000000002, mode=row)
#           )
#           (5): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.15, mode=row)
#           )
#           (6): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.155, mode=row)
#           )
#           (7): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#           )
#           (8): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.165, mode=row)
#           )
#           (9): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.17, mode=row)
#           )
#           (10): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.175, mode=row)
#           )
#           (11): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.18, mode=row)
#           )
#           (12): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.185, mode=row)
#           )
#           (13): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.19, mode=row)
#           )
#           (14): MBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (1): Conv2dNormActivation(
#                 (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#               (2): SqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#                 (activation): SiLU(inplace=True)
#                 (scale_activation): Sigmoid()
#               )
#               (3): Conv2dNormActivation(
#                 (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.195, mode=row)
#           )
#         )
#         (7): Conv2dNormActivation(
#           (0): Conv2d(256, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=1)
#       (classifier): Identity()
#     )
#   )
#   (protein_branch): Sequential(
#     (0): Linear(in_features=1280, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (fat_branch): Sequential(
#     (0): Linear(in_features=1280, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (carbs_branch): Sequential(
#     (0): Linear(in_features=1280, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (mass_branch): Sequential(
#     (0): Linear(in_features=1280, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
import sys
sys.path.append('/content/drive/MyDrive/CV_2024/FinalProject/nutri_estimate/nutri_estimate/final_model_combined')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/CV_2024/FinalProject/nutri_estimate/nutri_estimate/final_model_combined

# %%
# !dir
# Out:
# final_model  multi_regression_depth_combine.ipynb  scalers  utilities

# %%
# %pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install openmim
# !mim install mmengine
# !mim install mmcv==2.1.0
# !pip install addict yapf timm torchvision
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.1.0
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl (2200.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 953.5 kB/s eta 0:00:00
# Collecting torchvision==0.16.0
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.16.0%2Bcu121-cp310-cp310-linux_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 78.2 MB/s eta 0:00:00
# Collecting torchaudio==2.1.0
#   Downloading https://download.pytorch.org/whl/cu121/torchaudio-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (2024.10.0)
# Collecting triton==2.1.0 (from torch==2.1.0)
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0) (1.3.0)
# Installing collected packages: triton, torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu121
#     Uninstalling torchaudio-2.5.1+cu121:
#       Successfully uninstalled torchaudio-2.5.1+cu121
# Successfully installed torch-2.1.0+cu121 torchaudio-2.1.0+cu121 torchvision-0.16.0+cu121 triton-2.1.0
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.7)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.7)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (4.66.6)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.10/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.8 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.1 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 25.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 5.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 25.9 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.1 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 21.7 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 38.7 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.6 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 14.9 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 82.0 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 58.9 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 10.5 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=45f12d62ccf4e148ff595f5c5028101f77750f7561b7e42cc3f68fae78c76830
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535316 sha256=1cecf69f53b3d70d5a323899de9f4783632844e7e517148aaa79ba9776146872
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=461104a4e91427431d77f084ca3c92c6115e488bf751ec2a327d52ceac0f45a5
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, pycryptodome, ordered-set, jmespath, filelock, colorama, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# pymc 5.18.2 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# pytensor 2.26.4 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# yfinance 0.2.50 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 colorama-0.4.6 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 pycryptodome-3.21.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.10.5-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmengine) (1.26.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmengine) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine) (2.5.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.18.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (4.3.6)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (2.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Downloading mmengine-0.10.5-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.3/452.3 kB 16.6 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 23.5 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine
# Successfully installed addict-2.4.0 mmengine-0.10.5 yapf-0.43.0
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmcv==2.1.0
#   Downloading https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/mmcv-2.1.0-cp310-cp310-manylinux1_x86_64.whl (94.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (0.10.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (11.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (6.0.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.8.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (2.5.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv==2.1.0) (4.3.6)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv==2.1.0) (2.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.1.0
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (0.43.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (1.0.12)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf) (4.3.6)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf) (2.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.26.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->timm) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2024.10.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.1.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.65.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)

# %%
import os
import torch
from torchvision import transforms
import numpy as np
from sklearn.metrics import mean_absolute_error
from utilities.load_model import load_depth_model, load_custom_model
import joblib

depth_model = load_depth_model()
multi_task_model_path = os.path.join("final_model", "final_multi_task_model.pth")
model = load_custom_model(multi_task_model_path)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
depth_model = depth_model.to(device)

# Load scalers for inverse scaling later
scaler_directory = "scalers"
scalers = {}
for scaler_file in os.listdir(scaler_directory):
    scaler_name = scaler_file.replace("_scaler.save", "")
    scaler_path = os.path.join(scaler_directory, scaler_file)
    scalers[scaler_name] = joblib.load(scaler_path)

# Constants for Raspberry Pi camera, test set images come from Nutrition5k data that uses Raspberry Pi
FOCAL_LENGTH_MM = 2.75  # in mm
SENSOR_WIDTH_MM = 7.4   # in mm

# Eval loop
y_true, y_pred = {k: [] for k in ['protein', 'fat', 'carbs', 'mass']}, {k: [] for k in ['protein', 'fat', 'carbs', 'mass']}

with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(test_loader):
        images = images.to(device)
        input_dict = {"input": images}
        output = depth_model.inference(input_dict)
        pred_depth = output[0]  # Depth prediction

        # Extract depth scaling factors for each image in the batch
        batch_scaling_factors = []
        for img_idx in range(images.size(0)):
            height, width = images[img_idx].shape[1:3]
            depth_map = pred_depth[img_idx].squeeze().cpu().numpy()

            # Focal length + scaling logic
            focal_length = FOCAL_LENGTH_MM
            sensor_width = SENSOR_WIDTH_MM
            focal_length = focal_length / sensor_width * width if focal_length else 1.0
            canonical_to_real_scale = focal_length / 1000.0 if focal_length else 1.0
            depth_map = depth_map * canonical_to_real_scale
            depth_map = np.clip(depth_map, 0, 300)

            center_x, center_y = depth_map.shape[1] // 2, depth_map.shape[0] // 2
            center_depth = depth_map[center_y, center_x] / 1000  # convert mm to meters
            scaling_factor = center_depth / 0.4

            batch_scaling_factors.append(scaling_factor)
            print(f"Image {batch_idx * images.size(0) + img_idx}: Center Depth (m) = {center_depth:.4f}, Scaling Factor = {scaling_factor:.4f}")
            print(f"  Depth Map Min = {depth_map.min():.4f}, Max = {depth_map.max():.4f}")

        outputs = model(images)

        for img_idx in range(images.size(0)):
            for key in outputs:
                raw_predictions = outputs[key][img_idx].cpu().numpy()
                scaled_predictions = raw_predictions * batch_scaling_factors[img_idx]

                # Model trained on scaled data, outputs normalized data so need to inverse the scaling
                scaler_key = f"total_{key[:-1]}" if key == "carbs" else f"total_{key}"
                if scaler_key in scalers:
                    scaled_predictions = scalers[scaler_key].inverse_transform(
                        scaled_predictions.reshape(-1, 1)
                    ).flatten()

                print(f"Predictions Shape for Key {key}, Image {img_idx}: {scaled_predictions.shape}")
                y_pred[key].append(scaled_predictions.reshape(1))
                print(f"Label Shape for Key {key}, Image {img_idx}: {labels[key][img_idx].shape}")
                y_true[key].append(np.array([labels[key][img_idx].cpu().numpy()]))

                print(f"Image {batch_idx * images.size(0) + img_idx}, Key: {key}")
                print(f"  Scaling Factor: {batch_scaling_factors[img_idx]:.4f}")
                print(f"  Scaled Predictions: {scaled_predictions}")
                print(f"  True Values: {labels[key][img_idx].cpu().numpy()}")

# Combine predictions and true values
for key in y_pred:
    y_pred[key] = np.concatenate(y_pred[key], axis=0)
    y_true[key] = np.concatenate(y_true[key], axis=0)
    print(f"Combined Values for Key: {key}")
    print(f"  Predictions - Min={y_pred[key].min():.2f}, Max={y_pred[key].max():.2f}")
    print(f"  True Values - Min={y_true[key].min():.2f}, Max={y_true[key].max():.2f}")

# Calculate and print MAE
for key in y_pred:
    mae = mean_absolute_error(y_true[key], y_pred[key])
    print(f"{key.capitalize()} MAE: {mae:.2f}")
# Out:
# Using cache found in /root/.cache/torch/hub/yvanyin_metric3d_main
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.10/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# WARNING:dinov2:xFormers not available
# WARNING:dinov2:xFormers not available
# WARNING:dinov2:xFormers not available
# WARNING:dinov2:xFormers not available
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Image 9485, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [8.070388]
#   True Values: 19.408112938
# Predictions Shape for Key fat, Image 13: (1,)
# Label Shape for Key fat, Image 13: torch.Size([])
# Image 9485, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [4.507807]
#   True Values: 3.534456612
# Predictions Shape for Key carbs, Image 13: (1,)
# Label Shape for Key carbs, Image 13: torch.Size([])
# Image 9485, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [11.449503]
#   True Values: 2.233993911
# Predictions Shape for Key mass, Image 13: (1,)
# Label Shape for Key mass, Image 13: torch.Size([])
# Image 9485, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [156.25307]
#   True Values: 78.0
# Predictions Shape for Key protein, Image 14: (1,)
# Label Shape for Key protein, Image 14: torch.Size([])
# Image 9486, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [5.15501]
#   True Values: 19.408112938
# Predictions Shape for Key fat, Image 14: (1,)
# Label Shape for Key fat, Image 14: torch.Size([])
# Image 9486, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [3.1930556]
#   True Values: 3.534456612
# Predictions Shape for Key carbs, Image 14: (1,)
# Label Shape for Key carbs, Image 14: torch.Size([])
# Image 9486, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [9.245142]
#   True Values: 2.233993911
# Predictions Shape for Key mass, Image 14: (1,)
# Label Shape for Key mass, Image 14: torch.Size([])
# Image 9486, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [61.17253]
#   True Values: 78.0
# Predictions Shape for Key protein, Image 15: (1,)
# Label Shape for Key protein, Image 15: torch.Size([])
# Image 9487, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [3.0022497]
#   True Values: 19.408112938
# Predictions Shape for Key fat, Image 15: (1,)
# Label Shape for Key fat, Image 15: torch.Size([])
# Image 9487, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [6.3611937]
#   True Values: 3.534456612
# Predictions Shape for Key carbs, Image 15: (1,)
# Label Shape for Key carbs, Image 15: torch.Size([])
# Image 9487, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [5.822108]
#   True Values: 2.233993911
# Predictions Shape for Key mass, Image 15: (1,)
# Label Shape for Key mass, Image 15: torch.Size([])
# Image 9487, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [66.08837]
#   True Values: 78.0
# Image 9488: Center Depth (m) = 0.0002, Scaling Factor = 0.0005
#   Depth Map Min = 0.1768, Max = 0.2189
# Image 9489: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1306, Max = 0.1372
# Image 9490: Center Depth (m) = 0.0003, Scaling Factor = 0.0008
#   Depth Map Min = 0.2965, Max = 0.4063
# Image 9491: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1137, Max = 0.1406
# Image 9492: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0561, Max = 0.0878
# Image 9493: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0583, Max = 0.0971
# Image 9494: Center Depth (m) = 0.0002, Scaling Factor = 0.0006
#   Depth Map Min = 0.2387, Max = 10.6321
# Image 9495: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.0862, Max = 0.1510
# Image 9496: Center Depth (m) = 0.0002, Scaling Factor = 0.0004
#   Depth Map Min = 0.0887, Max = 0.1888
# Image 9497: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1116, Max = 0.1616
# Image 9498: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.0961, Max = 0.1140
# Image 9499: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0745, Max = 0.0877
# Image 9500: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0892, Max = 0.1524
# Image 9501: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0816, Max = 0.0958
# Image 9502: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0617, Max = 0.1362
# Image 9503: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0758, Max = 0.1684
# Predictions Shape for Key protein, Image 0: (1,)
# Label Shape for Key protein, Image 0: torch.Size([])
# Image 9488, Key: protein
#   Scaling Factor: 0.0005
#   Scaled Predictions: [6.0151415]
#   True Values: 19.408112938
# Predictions Shape for Key fat, Image 0: (1,)
# Label Shape for Key fat, Image 0: torch.Size([])
# Image 9488, Key: fat
#   Scaling Factor: 0.0005
#   Scaled Predictions: [6.710354]
#   True Values: 3.534456612
# Predictions Shape for Key carbs, Image 0: (1,)
# Label Shape for Key carbs, Image 0: torch.Size([])
# Image 9488, Key: carbs
#   Scaling Factor: 0.0005
#   Scaled Predictions: [10.224415]
#   True Values: 2.233993911
# Predictions Shape for Key mass, Image 0: (1,)
# Label Shape for Key mass, Image 0: torch.Size([])
# Image 9488, Key: mass
#   Scaling Factor: 0.0005
#   Scaled Predictions: [106.39297]
#   True Values: 78.0
# Predictions Shape for Key protein, Image 1: (1,)
# Label Shape for Key protein, Image 1: torch.Size([])
# Image 9489, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [4.54413]
#   True Values: 19.408112938
# Predictions Shape for Key fat, Image 1: (1,)
# Label Shape for Key fat, Image 1: torch.Size([])
# Image 9489, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [4.2853804]
#   True Values: 3.534456612
# Predictions Shape for Key carbs, Image 1: (1,)
# Label Shape for Key carbs, Image 1: torch.Size([])
# Image 9489, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [13.059918]
#   True Values: 2.233993911
# Predictions Shape for Key mass, Image 1: (1,)
# Label Shape for Key mass, Image 1: torch.Size([])
# Image 9489, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [71.2395]
#   True Values: 78.0
# Predictions Shape for Key protein, Image 2: (1,)
# Label Shape for Key protein, Image 2: torch.Size([])
# Image 9490, Key: protein
#   Scaling Factor: 0.0008
#   Scaled Predictions: [31.74157]
#   True Values: 3.354
# Predictions Shape for Key fat, Image 2: (1,)
# Label Shape for Key fat, Image 2: torch.Size([])
# Image 9490, Key: fat
#   Scaling Factor: 0.0008
#   Scaled Predictions: [18.17656]
#   True Values: 28.38
# Predictions Shape for Key carbs, Image 2: (1,)
# Label Shape for Key carbs, Image 2: torch.Size([])
# Image 9490, Key: carbs
#   Scaling Factor: 0.0008
#   Scaled Predictions: [11.037662]
#   True Values: 41.28
# Predictions Shape for Key mass, Image 2: (1,)
# Label Shape for Key mass, Image 2: torch.Size([])
# Image 9490, Key: mass
#   Scaling Factor: 0.0008
#   Scaled Predictions: [203.15686]
#   True Values: 129.0
# Predictions Shape for Key protein, Image 3: (1,)
# Label Shape for Key protein, Image 3: torch.Size([])
# Image 9491, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [13.282502]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 3: (1,)
# Label Shape for Key fat, Image 3: torch.Size([])
# Image 9491, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [38.657536]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 3: (1,)
# Label Shape for Key carbs, Image 3: torch.Size([])
# Image 9491, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [41.33296]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 3: (1,)
# Label Shape for Key mass, Image 3: torch.Size([])
# Image 9491, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [285.74475]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 4: (1,)
# Label Shape for Key protein, Image 4: torch.Size([])
# Image 9492, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [11.413208]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 4: (1,)
# Label Shape for Key fat, Image 4: torch.Size([])
# Image 9492, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [41.167778]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 4: (1,)
# Label Shape for Key carbs, Image 4: torch.Size([])
# Image 9492, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [40.262184]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 4: (1,)
# Label Shape for Key mass, Image 4: torch.Size([])
# Image 9492, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [245.55272]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 5: (1,)
# Label Shape for Key protein, Image 5: torch.Size([])
# Image 9493, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [25.133917]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 5: (1,)
# Label Shape for Key fat, Image 5: torch.Size([])
# Image 9493, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [18.99011]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 5: (1,)
# Label Shape for Key carbs, Image 5: torch.Size([])
# Image 9493, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.565617]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 5: (1,)
# Label Shape for Key mass, Image 5: torch.Size([])
# Image 9493, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [308.71832]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 6: (1,)
# Label Shape for Key protein, Image 6: torch.Size([])
# Image 9494, Key: protein
#   Scaling Factor: 0.0006
#   Scaled Predictions: [2.5474133]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 6: (1,)
# Label Shape for Key fat, Image 6: torch.Size([])
# Image 9494, Key: fat
#   Scaling Factor: 0.0006
#   Scaled Predictions: [2.2373629]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 6: (1,)
# Label Shape for Key carbs, Image 6: torch.Size([])
# Image 9494, Key: carbs
#   Scaling Factor: 0.0006
#   Scaled Predictions: [9.040531]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 6: (1,)
# Label Shape for Key mass, Image 6: torch.Size([])
# Image 9494, Key: mass
#   Scaling Factor: 0.0006
#   Scaled Predictions: [94.71313]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 7: (1,)
# Label Shape for Key protein, Image 7: torch.Size([])
# Image 9495, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [2.0217433]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 7: (1,)
# Label Shape for Key fat, Image 7: torch.Size([])
# Image 9495, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [2.0762916]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 7: (1,)
# Label Shape for Key carbs, Image 7: torch.Size([])
# Image 9495, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [6.5690384]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 7: (1,)
# Label Shape for Key mass, Image 7: torch.Size([])
# Image 9495, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [55.680363]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 8: (1,)
# Label Shape for Key protein, Image 8: torch.Size([])
# Image 9496, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [19.03331]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 8: (1,)
# Label Shape for Key fat, Image 8: torch.Size([])
# Image 9496, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [14.936211]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 8: (1,)
# Label Shape for Key carbs, Image 8: torch.Size([])
# Image 9496, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [3.3604093]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 8: (1,)
# Label Shape for Key mass, Image 8: torch.Size([])
# Image 9496, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [191.61856]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 9: (1,)
# Label Shape for Key protein, Image 9: torch.Size([])
# Image 9497, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [13.100699]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 9: (1,)
# Label Shape for Key fat, Image 9: torch.Size([])
# Image 9497, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [38.525368]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 9: (1,)
# Label Shape for Key carbs, Image 9: torch.Size([])
# Image 9497, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [36.568798]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 9: (1,)
# Label Shape for Key mass, Image 9: torch.Size([])
# Image 9497, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [257.9748]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 10: (1,)
# Label Shape for Key protein, Image 10: torch.Size([])
# Image 9498, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [11.59663]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 10: (1,)
# Label Shape for Key fat, Image 10: torch.Size([])
# Image 9498, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [37.70228]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 10: (1,)
# Label Shape for Key carbs, Image 10: torch.Size([])
# Image 9498, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [40.583984]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 10: (1,)
# Label Shape for Key mass, Image 10: torch.Size([])
# Image 9498, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [272.17123]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 11: (1,)
# Label Shape for Key protein, Image 11: torch.Size([])
# Image 9499, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [23.06682]
#   True Values: 15.488
# Predictions Shape for Key fat, Image 11: (1,)
# Label Shape for Key fat, Image 11: torch.Size([])
# Image 9499, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [24.396784]
#   True Values: 33.88
# Predictions Shape for Key carbs, Image 11: (1,)
# Label Shape for Key carbs, Image 11: torch.Size([])
# Image 9499, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [34.46566]
#   True Values: 30.272
# Predictions Shape for Key mass, Image 11: (1,)
# Label Shape for Key mass, Image 11: torch.Size([])
# Image 9499, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [246.74805]
#   True Values: 220.0
# Predictions Shape for Key protein, Image 12: (1,)
# Label Shape for Key protein, Image 12: torch.Size([])
# Image 9500, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [8.003954]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 12: (1,)
# Label Shape for Key fat, Image 12: torch.Size([])
# Image 9500, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.682764]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 12: (1,)
# Label Shape for Key carbs, Image 12: torch.Size([])
# Image 9500, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [14.71455]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 12: (1,)
# Label Shape for Key mass, Image 12: torch.Size([])
# Image 9500, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [126.445816]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 13: (1,)
# Label Shape for Key protein, Image 13: torch.Size([])
# Image 9501, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.366465]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 13: (1,)
# Label Shape for Key fat, Image 13: torch.Size([])
# Image 9501, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.696398]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 13: (1,)
# Label Shape for Key carbs, Image 13: torch.Size([])
# Image 9501, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [14.784345]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 13: (1,)
# Label Shape for Key mass, Image 13: torch.Size([])
# Image 9501, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [142.26627]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 14: (1,)
# Label Shape for Key protein, Image 14: torch.Size([])
# Image 9502, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.9441957]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 14: (1,)
# Label Shape for Key fat, Image 14: torch.Size([])
# Image 9502, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.199585]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 14: (1,)
# Label Shape for Key carbs, Image 14: torch.Size([])
# Image 9502, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [20.279078]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 14: (1,)
# Label Shape for Key mass, Image 14: torch.Size([])
# Image 9502, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [167.13313]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 15: (1,)
# Label Shape for Key protein, Image 15: torch.Size([])
# Image 9503, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [15.516365]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 15: (1,)
# Label Shape for Key fat, Image 15: torch.Size([])
# Image 9503, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [10.089373]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 15: (1,)
# Label Shape for Key carbs, Image 15: torch.Size([])
# Image 9503, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [19.292637]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 15: (1,)
# Label Shape for Key mass, Image 15: torch.Size([])
# Image 9503, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [178.48145]
#   True Values: 150.0
# Image 9504: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1051, Max = 0.1569
# Image 9505: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0490, Max = 0.1230
# Image 9506: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0682, Max = 0.0822
# Image 9507: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0762, Max = 0.1311
# Image 9508: Center Depth (m) = 0.0002, Scaling Factor = 0.0004
#   Depth Map Min = 0.1441, Max = 0.1610
# Image 9509: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0685, Max = 0.1249
# Image 9510: Center Depth (m) = 0.0001, Scaling Factor = 0.0001
#   Depth Map Min = 0.0499, Max = 0.0642
# Image 9511: Center Depth (m) = 0.0002, Scaling Factor = 0.0004
#   Depth Map Min = 0.1692, Max = 0.2128
# Image 9512: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0672, Max = 0.1304
# Image 9513: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1100, Max = 0.1609
# Image 9514: Center Depth (m) = 0.0001, Scaling Factor = 0.0001
#   Depth Map Min = 0.0462, Max = 0.0862
# Image 9515: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0725, Max = 0.0928
# Image 9516: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0536, Max = 0.0858
# Image 9517: Center Depth (m) = 0.0001, Scaling Factor = 0.0004
#   Depth Map Min = 0.1446, Max = 0.1665
# Image 9518: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1206, Max = 0.1394
# Image 9519: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0638, Max = 0.0942
# Predictions Shape for Key protein, Image 0: (1,)
# Label Shape for Key protein, Image 0: torch.Size([])
# Image 9504, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [16.589182]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 0: (1,)
# Label Shape for Key fat, Image 0: torch.Size([])
# Image 9504, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [22.405418]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 0: (1,)
# Label Shape for Key carbs, Image 0: torch.Size([])
# Image 9504, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [16.873947]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 0: (1,)
# Label Shape for Key mass, Image 0: torch.Size([])
# Image 9504, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [150.77277]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 1: (1,)
# Label Shape for Key protein, Image 1: torch.Size([])
# Image 9505, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.152188]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 1: (1,)
# Label Shape for Key fat, Image 1: torch.Size([])
# Image 9505, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [11.485874]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 1: (1,)
# Label Shape for Key carbs, Image 1: torch.Size([])
# Image 9505, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [19.109457]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 1: (1,)
# Label Shape for Key mass, Image 1: torch.Size([])
# Image 9505, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [157.82674]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 2: (1,)
# Label Shape for Key protein, Image 2: torch.Size([])
# Image 9506, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [6.1939416]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 2: (1,)
# Label Shape for Key fat, Image 2: torch.Size([])
# Image 9506, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [6.0163517]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 2: (1,)
# Label Shape for Key carbs, Image 2: torch.Size([])
# Image 9506, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [16.032722]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 2: (1,)
# Label Shape for Key mass, Image 2: torch.Size([])
# Image 9506, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [112.268524]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 3: (1,)
# Label Shape for Key protein, Image 3: torch.Size([])
# Image 9507, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.919437]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 3: (1,)
# Label Shape for Key fat, Image 3: torch.Size([])
# Image 9507, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [5.4320807]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 3: (1,)
# Label Shape for Key carbs, Image 3: torch.Size([])
# Image 9507, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [11.134604]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 3: (1,)
# Label Shape for Key mass, Image 3: torch.Size([])
# Image 9507, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [116.978165]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 4: (1,)
# Label Shape for Key protein, Image 4: torch.Size([])
# Image 9508, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [6.0065]
#   True Values: 11.882043771
# Predictions Shape for Key fat, Image 4: (1,)
# Label Shape for Key fat, Image 4: torch.Size([])
# Image 9508, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [5.916036]
#   True Values: 8.854575158
# Predictions Shape for Key carbs, Image 4: (1,)
# Label Shape for Key carbs, Image 4: torch.Size([])
# Image 9508, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [18.121399]
#   True Values: 14.756506908
# Predictions Shape for Key mass, Image 4: (1,)
# Label Shape for Key mass, Image 4: torch.Size([])
# Image 9508, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [119.73787]
#   True Values: 150.0
# Predictions Shape for Key protein, Image 5: (1,)
# Label Shape for Key protein, Image 5: torch.Size([])
# Image 9509, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [1.6418179]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 5: (1,)
# Label Shape for Key fat, Image 5: torch.Size([])
# Image 9509, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [0.6097019]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 5: (1,)
# Label Shape for Key carbs, Image 5: torch.Size([])
# Image 9509, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [6.3599534]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 5: (1,)
# Label Shape for Key mass, Image 5: torch.Size([])
# Image 9509, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [98.15451]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 6: (1,)
# Label Shape for Key protein, Image 6: torch.Size([])
# Image 9510, Key: protein
#   Scaling Factor: 0.0001
#   Scaled Predictions: [2.0814264]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 6: (1,)
# Label Shape for Key fat, Image 6: torch.Size([])
# Image 9510, Key: fat
#   Scaling Factor: 0.0001
#   Scaled Predictions: [0.88017255]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 6: (1,)
# Label Shape for Key carbs, Image 6: torch.Size([])
# Image 9510, Key: carbs
#   Scaling Factor: 0.0001
#   Scaled Predictions: [6.498274]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 6: (1,)
# Label Shape for Key mass, Image 6: torch.Size([])
# Image 9510, Key: mass
#   Scaling Factor: 0.0001
#   Scaled Predictions: [112.59367]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 7: (1,)
# Label Shape for Key protein, Image 7: torch.Size([])
# Image 9511, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [1.7635888]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 7: (1,)
# Label Shape for Key fat, Image 7: torch.Size([])
# Image 9511, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [-0.16092551]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 7: (1,)
# Label Shape for Key carbs, Image 7: torch.Size([])
# Image 9511, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [4.240383]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 7: (1,)
# Label Shape for Key mass, Image 7: torch.Size([])
# Image 9511, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [101.410706]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 8: (1,)
# Label Shape for Key protein, Image 8: torch.Size([])
# Image 9512, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [2.3774474]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 8: (1,)
# Label Shape for Key fat, Image 8: torch.Size([])
# Image 9512, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [0.92781013]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 8: (1,)
# Label Shape for Key carbs, Image 8: torch.Size([])
# Image 9512, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.736277]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 8: (1,)
# Label Shape for Key mass, Image 8: torch.Size([])
# Image 9512, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [161.83678]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 9: (1,)
# Label Shape for Key protein, Image 9: torch.Size([])
# Image 9513, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [6.7997475]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 9: (1,)
# Label Shape for Key fat, Image 9: torch.Size([])
# Image 9513, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [6.645587]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 9: (1,)
# Label Shape for Key carbs, Image 9: torch.Size([])
# Image 9513, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [18.943428]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 9: (1,)
# Label Shape for Key mass, Image 9: torch.Size([])
# Image 9513, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [206.80336]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 10: (1,)
# Label Shape for Key protein, Image 10: torch.Size([])
# Image 9514, Key: protein
#   Scaling Factor: 0.0001
#   Scaled Predictions: [1.735163]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 10: (1,)
# Label Shape for Key fat, Image 10: torch.Size([])
# Image 9514, Key: fat
#   Scaling Factor: 0.0001
#   Scaled Predictions: [0.29897198]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 10: (1,)
# Label Shape for Key carbs, Image 10: torch.Size([])
# Image 9514, Key: carbs
#   Scaling Factor: 0.0001
#   Scaled Predictions: [2.8060057]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 10: (1,)
# Label Shape for Key mass, Image 10: torch.Size([])
# Image 9514, Key: mass
#   Scaling Factor: 0.0001
#   Scaled Predictions: [64.03186]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 11: (1,)
# Label Shape for Key protein, Image 11: torch.Size([])
# Image 9515, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [2.0310996]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 11: (1,)
# Label Shape for Key fat, Image 11: torch.Size([])
# Image 9515, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [0.37464246]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 11: (1,)
# Label Shape for Key carbs, Image 11: torch.Size([])
# Image 9515, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [6.194041]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 11: (1,)
# Label Shape for Key mass, Image 11: torch.Size([])
# Image 9515, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [100.095345]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 12: (1,)
# Label Shape for Key protein, Image 12: torch.Size([])
# Image 9516, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [1.7159804]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 12: (1,)
# Label Shape for Key fat, Image 12: torch.Size([])
# Image 9516, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [0.392186]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 12: (1,)
# Label Shape for Key carbs, Image 12: torch.Size([])
# Image 9516, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [5.6569133]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 12: (1,)
# Label Shape for Key mass, Image 12: torch.Size([])
# Image 9516, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [120.604706]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 13: (1,)
# Label Shape for Key protein, Image 13: torch.Size([])
# Image 9517, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [1.9551668]
#   True Values: 0.6000000000000001
# Predictions Shape for Key fat, Image 13: (1,)
# Label Shape for Key fat, Image 13: torch.Size([])
# Image 9517, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [1.3323321]
#   True Values: 0.0
# Predictions Shape for Key carbs, Image 13: (1,)
# Label Shape for Key carbs, Image 13: torch.Size([])
# Image 9517, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [5.6853857]
#   True Values: 1.2
# Predictions Shape for Key mass, Image 13: (1,)
# Label Shape for Key mass, Image 13: torch.Size([])
# Image 9517, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [91.1813]
#   True Values: 60.0
# Predictions Shape for Key protein, Image 14: (1,)
# Label Shape for Key protein, Image 14: torch.Size([])
# Image 9518, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [9.518646]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 14: (1,)
# Label Shape for Key fat, Image 14: torch.Size([])
# Image 9518, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [8.650606]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 14: (1,)
# Label Shape for Key carbs, Image 14: torch.Size([])
# Image 9518, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [15.991796]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 14: (1,)
# Label Shape for Key mass, Image 14: torch.Size([])
# Image 9518, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [130.90065]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 15: (1,)
# Label Shape for Key protein, Image 15: torch.Size([])
# Image 9519, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.5221725]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 15: (1,)
# Label Shape for Key fat, Image 15: torch.Size([])
# Image 9519, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [5.8662715]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 15: (1,)
# Label Shape for Key carbs, Image 15: torch.Size([])
# Image 9519, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [6.4791493]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 15: (1,)
# Label Shape for Key mass, Image 15: torch.Size([])
# Image 9519, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [96.09854]
#   True Values: 71.0
# Image 9520: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.0960, Max = 0.1427
# Image 9521: Center Depth (m) = 0.0001, Scaling Factor = 0.0004
#   Depth Map Min = 0.1301, Max = 0.1881
# Image 9522: Center Depth (m) = 0.0002, Scaling Factor = 0.0006
#   Depth Map Min = 0.1496, Max = 0.3168
# Image 9523: Center Depth (m) = 0.0002, Scaling Factor = 0.0005
#   Depth Map Min = 0.1445, Max = 0.2298
# Image 9524: Center Depth (m) = 0.0001, Scaling Factor = 0.0004
#   Depth Map Min = 0.1081, Max = 0.1537
# Image 9525: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0914, Max = 0.1061
# Image 9526: Center Depth (m) = 0.0000, Scaling Factor = 0.0001
#   Depth Map Min = 0.0143, Max = 0.0382
# Image 9527: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1133, Max = 0.2329
# Image 9528: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0908, Max = 0.1057
# Image 9529: Center Depth (m) = 0.0001, Scaling Factor = 0.0004
#   Depth Map Min = 0.1443, Max = 0.1781
# Image 9530: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1126, Max = 0.2084
# Image 9531: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0856, Max = 0.1402
# Image 9532: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0636, Max = 0.1443
# Image 9533: Center Depth (m) = 0.0002, Scaling Factor = 0.0005
#   Depth Map Min = 0.1864, Max = 0.2287
# Image 9534: Center Depth (m) = 0.0000, Scaling Factor = 0.0001
#   Depth Map Min = 0.0412, Max = 0.0709
# Image 9535: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.1004, Max = 0.1299
# Predictions Shape for Key protein, Image 0: (1,)
# Label Shape for Key protein, Image 0: torch.Size([])
# Image 9520, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [2.0508888]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 0: (1,)
# Label Shape for Key fat, Image 0: torch.Size([])
# Image 9520, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [1.262385]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 0: (1,)
# Label Shape for Key carbs, Image 0: torch.Size([])
# Image 9520, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [7.8297563]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 0: (1,)
# Label Shape for Key mass, Image 0: torch.Size([])
# Image 9520, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [73.799034]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 1: (1,)
# Label Shape for Key protein, Image 1: torch.Size([])
# Image 9521, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [8.058412]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 1: (1,)
# Label Shape for Key fat, Image 1: torch.Size([])
# Image 9521, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [3.0887873]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 1: (1,)
# Label Shape for Key carbs, Image 1: torch.Size([])
# Image 9521, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [18.023178]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 1: (1,)
# Label Shape for Key mass, Image 1: torch.Size([])
# Image 9521, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [202.1999]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 2: (1,)
# Label Shape for Key protein, Image 2: torch.Size([])
# Image 9522, Key: protein
#   Scaling Factor: 0.0006
#   Scaled Predictions: [2.5578525]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 2: (1,)
# Label Shape for Key fat, Image 2: torch.Size([])
# Image 9522, Key: fat
#   Scaling Factor: 0.0006
#   Scaled Predictions: [1.5401678]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 2: (1,)
# Label Shape for Key carbs, Image 2: torch.Size([])
# Image 9522, Key: carbs
#   Scaling Factor: 0.0006
#   Scaled Predictions: [7.549124]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 2: (1,)
# Label Shape for Key mass, Image 2: torch.Size([])
# Image 9522, Key: mass
#   Scaling Factor: 0.0006
#   Scaled Predictions: [72.16601]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 3: (1,)
# Label Shape for Key protein, Image 3: torch.Size([])
# Image 9523, Key: protein
#   Scaling Factor: 0.0005
#   Scaled Predictions: [5.624971]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 3: (1,)
# Label Shape for Key fat, Image 3: torch.Size([])
# Image 9523, Key: fat
#   Scaling Factor: 0.0005
#   Scaled Predictions: [2.7046776]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 3: (1,)
# Label Shape for Key carbs, Image 3: torch.Size([])
# Image 9523, Key: carbs
#   Scaling Factor: 0.0005
#   Scaled Predictions: [5.176476]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 3: (1,)
# Label Shape for Key mass, Image 3: torch.Size([])
# Image 9523, Key: mass
#   Scaling Factor: 0.0005
#   Scaled Predictions: [101.965675]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 4: (1,)
# Label Shape for Key protein, Image 4: torch.Size([])
# Image 9524, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [4.279997]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 4: (1,)
# Label Shape for Key fat, Image 4: torch.Size([])
# Image 9524, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [9.98639]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 4: (1,)
# Label Shape for Key carbs, Image 4: torch.Size([])
# Image 9524, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [10.445364]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 4: (1,)
# Label Shape for Key mass, Image 4: torch.Size([])
# Image 9524, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [64.60912]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 5: (1,)
# Label Shape for Key protein, Image 5: torch.Size([])
# Image 9525, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [12.147979]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 5: (1,)
# Label Shape for Key fat, Image 5: torch.Size([])
# Image 9525, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [7.40715]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 5: (1,)
# Label Shape for Key carbs, Image 5: torch.Size([])
# Image 9525, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [15.707409]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 5: (1,)
# Label Shape for Key mass, Image 5: torch.Size([])
# Image 9525, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [127.83828]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 6: (1,)
# Label Shape for Key protein, Image 6: torch.Size([])
# Image 9526, Key: protein
#   Scaling Factor: 0.0001
#   Scaled Predictions: [14.969126]
#   True Values: 3.111562078
# Predictions Shape for Key fat, Image 6: (1,)
# Label Shape for Key fat, Image 6: torch.Size([])
# Image 9526, Key: fat
#   Scaling Factor: 0.0001
#   Scaled Predictions: [9.623738]
#   True Values: 0.586656923
# Predictions Shape for Key carbs, Image 6: (1,)
# Label Shape for Key carbs, Image 6: torch.Size([])
# Image 9526, Key: carbs
#   Scaling Factor: 0.0001
#   Scaled Predictions: [4.6758547]
#   True Values: 14.177196924
# Predictions Shape for Key mass, Image 6: (1,)
# Label Shape for Key mass, Image 6: torch.Size([])
# Image 9526, Key: mass
#   Scaling Factor: 0.0001
#   Scaled Predictions: [92.19714]
#   True Values: 71.0
# Predictions Shape for Key protein, Image 7: (1,)
# Label Shape for Key protein, Image 7: torch.Size([])
# Image 9527, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [5.290851]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 7: (1,)
# Label Shape for Key fat, Image 7: torch.Size([])
# Image 9527, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [6.7689877]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 7: (1,)
# Label Shape for Key carbs, Image 7: torch.Size([])
# Image 9527, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [10.090408]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 7: (1,)
# Label Shape for Key mass, Image 7: torch.Size([])
# Image 9527, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [170.00655]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 8: (1,)
# Label Shape for Key protein, Image 8: torch.Size([])
# Image 9528, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [3.6811175]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 8: (1,)
# Label Shape for Key fat, Image 8: torch.Size([])
# Image 9528, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [1.9234576]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 8: (1,)
# Label Shape for Key carbs, Image 8: torch.Size([])
# Image 9528, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [21.858553]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 8: (1,)
# Label Shape for Key mass, Image 8: torch.Size([])
# Image 9528, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [202.8395]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 9: (1,)
# Label Shape for Key protein, Image 9: torch.Size([])
# Image 9529, Key: protein
#   Scaling Factor: 0.0004
#   Scaled Predictions: [8.579094]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 9: (1,)
# Label Shape for Key fat, Image 9: torch.Size([])
# Image 9529, Key: fat
#   Scaling Factor: 0.0004
#   Scaled Predictions: [13.524536]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 9: (1,)
# Label Shape for Key carbs, Image 9: torch.Size([])
# Image 9529, Key: carbs
#   Scaling Factor: 0.0004
#   Scaled Predictions: [9.970988]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 9: (1,)
# Label Shape for Key mass, Image 9: torch.Size([])
# Image 9529, Key: mass
#   Scaling Factor: 0.0004
#   Scaled Predictions: [122.472435]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 10: (1,)
# Label Shape for Key protein, Image 10: torch.Size([])
# Image 9530, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [5.6124997]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 10: (1,)
# Label Shape for Key fat, Image 10: torch.Size([])
# Image 9530, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [5.473666]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 10: (1,)
# Label Shape for Key carbs, Image 10: torch.Size([])
# Image 9530, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [10.360252]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 10: (1,)
# Label Shape for Key mass, Image 10: torch.Size([])
# Image 9530, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [156.24205]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 11: (1,)
# Label Shape for Key protein, Image 11: torch.Size([])
# Image 9531, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [16.412903]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 11: (1,)
# Label Shape for Key fat, Image 11: torch.Size([])
# Image 9531, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [25.33432]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 11: (1,)
# Label Shape for Key carbs, Image 11: torch.Size([])
# Image 9531, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.455667]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 11: (1,)
# Label Shape for Key mass, Image 11: torch.Size([])
# Image 9531, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [155.01872]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 12: (1,)
# Label Shape for Key protein, Image 12: torch.Size([])
# Image 9532, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [4.5008965]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 12: (1,)
# Label Shape for Key fat, Image 12: torch.Size([])
# Image 9532, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.443528]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 12: (1,)
# Label Shape for Key carbs, Image 12: torch.Size([])
# Image 9532, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [13.78982]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 12: (1,)
# Label Shape for Key mass, Image 12: torch.Size([])
# Image 9532, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [137.90935]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 13: (1,)
# Label Shape for Key protein, Image 13: torch.Size([])
# Image 9533, Key: protein
#   Scaling Factor: 0.0005
#   Scaled Predictions: [2.7992706]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 13: (1,)
# Label Shape for Key fat, Image 13: torch.Size([])
# Image 9533, Key: fat
#   Scaling Factor: 0.0005
#   Scaled Predictions: [1.0842913]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 13: (1,)
# Label Shape for Key carbs, Image 13: torch.Size([])
# Image 9533, Key: carbs
#   Scaling Factor: 0.0005
#   Scaled Predictions: [26.389502]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 13: (1,)
# Label Shape for Key mass, Image 13: torch.Size([])
# Image 9533, Key: mass
#   Scaling Factor: 0.0005
#   Scaled Predictions: [168.36252]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 14: (1,)
# Label Shape for Key protein, Image 14: torch.Size([])
# Image 9534, Key: protein
#   Scaling Factor: 0.0001
#   Scaled Predictions: [13.421058]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 14: (1,)
# Label Shape for Key fat, Image 14: torch.Size([])
# Image 9534, Key: fat
#   Scaling Factor: 0.0001
#   Scaled Predictions: [16.009748]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 14: (1,)
# Label Shape for Key carbs, Image 14: torch.Size([])
# Image 9534, Key: carbs
#   Scaling Factor: 0.0001
#   Scaled Predictions: [8.523905]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 14: (1,)
# Label Shape for Key mass, Image 14: torch.Size([])
# Image 9534, Key: mass
#   Scaling Factor: 0.0001
#   Scaled Predictions: [158.81328]
#   True Values: 253.0
# Predictions Shape for Key protein, Image 15: (1,)
# Label Shape for Key protein, Image 15: torch.Size([])
# Image 9535, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [4.4063244]
#   True Values: 39.569679088
# Predictions Shape for Key fat, Image 15: (1,)
# Label Shape for Key fat, Image 15: torch.Size([])
# Image 9535, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [3.526852]
#   True Values: 12.475333373
# Predictions Shape for Key carbs, Image 15: (1,)
# Label Shape for Key carbs, Image 15: torch.Size([])
# Image 9535, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [9.748313]
#   True Values: 5.115485842
# Predictions Shape for Key mass, Image 15: (1,)
# Label Shape for Key mass, Image 15: torch.Size([])
# Image 9535, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [149.7288]
#   True Values: 253.0
# Image 9536: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0677, Max = 0.1012
# Image 9537: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0818, Max = 0.1074
# Image 9538: Center Depth (m) = 0.0001, Scaling Factor = 0.0003
#   Depth Map Min = 0.0864, Max = 0.1612
# ...
# Image 9659, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [25.87423]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 11: (1,)
# Label Shape for Key mass, Image 11: torch.Size([])
# Image 9659, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [381.2442]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 12: (1,)
# Label Shape for Key protein, Image 12: torch.Size([])
# Image 9660, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [21.763468]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 12: (1,)
# Label Shape for Key fat, Image 12: torch.Size([])
# Image 9660, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [21.590174]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 12: (1,)
# Label Shape for Key carbs, Image 12: torch.Size([])
# Image 9660, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [21.025684]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 12: (1,)
# Label Shape for Key mass, Image 12: torch.Size([])
# Image 9660, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [293.88187]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 13: (1,)
# Label Shape for Key protein, Image 13: torch.Size([])
# Image 9661, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [14.731083]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 13: (1,)
# Label Shape for Key fat, Image 13: torch.Size([])
# Image 9661, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [12.612283]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 13: (1,)
# Label Shape for Key carbs, Image 13: torch.Size([])
# Image 9661, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [18.747404]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 13: (1,)
# Label Shape for Key mass, Image 13: torch.Size([])
# Image 9661, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [239.11258]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 14: (1,)
# Label Shape for Key protein, Image 14: torch.Size([])
# Image 9662, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [36.277554]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 14: (1,)
# Label Shape for Key fat, Image 14: torch.Size([])
# Image 9662, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [38.96734]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 14: (1,)
# Label Shape for Key carbs, Image 14: torch.Size([])
# Image 9662, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [11.878069]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 14: (1,)
# Label Shape for Key mass, Image 14: torch.Size([])
# Image 9662, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [312.78513]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 15: (1,)
# Label Shape for Key protein, Image 15: torch.Size([])
# Image 9663, Key: protein
#   Scaling Factor: 0.0003
#   Scaled Predictions: [21.472263]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 15: (1,)
# Label Shape for Key fat, Image 15: torch.Size([])
# Image 9663, Key: fat
#   Scaling Factor: 0.0003
#   Scaled Predictions: [21.92869]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 15: (1,)
# Label Shape for Key carbs, Image 15: torch.Size([])
# Image 9663, Key: carbs
#   Scaling Factor: 0.0003
#   Scaled Predictions: [25.090956]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 15: (1,)
# Label Shape for Key mass, Image 15: torch.Size([])
# Image 9663, Key: mass
#   Scaling Factor: 0.0003
#   Scaled Predictions: [310.908]
#   True Values: 329.0
# Image 7852: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0949, Max = 0.1940
# Image 7853: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0959, Max = 0.1113
# Image 7854: Center Depth (m) = 0.0002, Scaling Factor = 0.0005
#   Depth Map Min = 0.2101, Max = 0.2476
# Image 7855: Center Depth (m) = 0.0002, Scaling Factor = 0.0006
#   Depth Map Min = 0.2233, Max = 0.2826
# Image 7856: Center Depth (m) = 0.0001, Scaling Factor = 0.0001
#   Depth Map Min = 0.0559, Max = 0.1184
# Image 7857: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0767, Max = 0.1032
# Image 7858: Center Depth (m) = 0.0003, Scaling Factor = 0.0006
#   Depth Map Min = 0.1914, Max = 0.3874
# Image 7859: Center Depth (m) = 0.0003, Scaling Factor = 0.0006
#   Depth Map Min = 0.2424, Max = 0.2959
# Image 7860: Center Depth (m) = 0.0003, Scaling Factor = 0.0007
#   Depth Map Min = 0.1825, Max = 0.3919
# Image 7861: Center Depth (m) = 0.0002, Scaling Factor = 0.0006
#   Depth Map Min = 0.1745, Max = 0.3502
# Image 7862: Center Depth (m) = 0.0001, Scaling Factor = 0.0002
#   Depth Map Min = 0.0880, Max = 0.1016
# Image 7863: Center Depth (m) = 0.0001, Scaling Factor = 0.0001
#   Depth Map Min = 0.0473, Max = 0.0728
# Image 7864: Center Depth (m) = 0.0002, Scaling Factor = 0.0005
#   Depth Map Min = 0.1846, Max = 0.2000
# Predictions Shape for Key protein, Image 0: (1,)
# Label Shape for Key protein, Image 0: torch.Size([])
# Image 7852, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [27.29872]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 0: (1,)
# Label Shape for Key fat, Image 0: torch.Size([])
# Image 7852, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [33.246586]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 0: (1,)
# Label Shape for Key carbs, Image 0: torch.Size([])
# Image 7852, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [10.886237]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 0: (1,)
# Label Shape for Key mass, Image 0: torch.Size([])
# Image 7852, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [225.70157]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 1: (1,)
# Label Shape for Key protein, Image 1: torch.Size([])
# Image 7853, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [18.54593]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 1: (1,)
# Label Shape for Key fat, Image 1: torch.Size([])
# Image 7853, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [19.282276]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 1: (1,)
# Label Shape for Key carbs, Image 1: torch.Size([])
# Image 7853, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [18.926476]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 1: (1,)
# Label Shape for Key mass, Image 1: torch.Size([])
# Image 7853, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [262.76486]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 2: (1,)
# Label Shape for Key protein, Image 2: torch.Size([])
# Image 7854, Key: protein
#   Scaling Factor: 0.0005
#   Scaled Predictions: [32.502342]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 2: (1,)
# Label Shape for Key fat, Image 2: torch.Size([])
# Image 7854, Key: fat
#   Scaling Factor: 0.0005
#   Scaled Predictions: [32.295135]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 2: (1,)
# Label Shape for Key carbs, Image 2: torch.Size([])
# Image 7854, Key: carbs
#   Scaling Factor: 0.0005
#   Scaled Predictions: [21.683071]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 2: (1,)
# Label Shape for Key mass, Image 2: torch.Size([])
# Image 7854, Key: mass
#   Scaling Factor: 0.0005
#   Scaled Predictions: [350.68646]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 3: (1,)
# Label Shape for Key protein, Image 3: torch.Size([])
# Image 7855, Key: protein
#   Scaling Factor: 0.0006
#   Scaled Predictions: [25.39631]
#   True Values: 19.478
# Predictions Shape for Key fat, Image 3: (1,)
# Label Shape for Key fat, Image 3: torch.Size([])
# Image 7855, Key: fat
#   Scaling Factor: 0.0006
#   Scaled Predictions: [20.865211]
#   True Values: 28.534
# Predictions Shape for Key carbs, Image 3: (1,)
# Label Shape for Key carbs, Image 3: torch.Size([])
# Image 7855, Key: carbs
#   Scaling Factor: 0.0006
#   Scaled Predictions: [37.347492]
#   True Values: 39.016
# Predictions Shape for Key mass, Image 3: (1,)
# Label Shape for Key mass, Image 3: torch.Size([])
# Image 7855, Key: mass
#   Scaling Factor: 0.0006
#   Scaled Predictions: [273.1633]
#   True Values: 329.0
# Predictions Shape for Key protein, Image 4: (1,)
# Label Shape for Key protein, Image 4: torch.Size([])
# Image 7856, Key: protein
#   Scaling Factor: 0.0001
#   Scaled Predictions: [5.6750116]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 4: (1,)
# Label Shape for Key fat, Image 4: torch.Size([])
# Image 7856, Key: fat
#   Scaling Factor: 0.0001
#   Scaled Predictions: [2.2289972]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 4: (1,)
# Label Shape for Key carbs, Image 4: torch.Size([])
# Image 7856, Key: carbs
#   Scaling Factor: 0.0001
#   Scaled Predictions: [8.848937]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 4: (1,)
# Label Shape for Key mass, Image 4: torch.Size([])
# Image 7856, Key: mass
#   Scaling Factor: 0.0001
#   Scaled Predictions: [138.16724]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 5: (1,)
# Label Shape for Key protein, Image 5: torch.Size([])
# Image 7857, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [2.4684553]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 5: (1,)
# Label Shape for Key fat, Image 5: torch.Size([])
# Image 7857, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [1.4276128]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 5: (1,)
# Label Shape for Key carbs, Image 5: torch.Size([])
# Image 7857, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [6.403297]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 5: (1,)
# Label Shape for Key mass, Image 5: torch.Size([])
# Image 7857, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [100.79752]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 6: (1,)
# Label Shape for Key protein, Image 6: torch.Size([])
# Image 7858, Key: protein
#   Scaling Factor: 0.0006
#   Scaled Predictions: [2.6067224]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 6: (1,)
# Label Shape for Key fat, Image 6: torch.Size([])
# Image 7858, Key: fat
#   Scaling Factor: 0.0006
#   Scaled Predictions: [1.4182351]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 6: (1,)
# Label Shape for Key carbs, Image 6: torch.Size([])
# Image 7858, Key: carbs
#   Scaling Factor: 0.0006
#   Scaled Predictions: [13.045682]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 6: (1,)
# Label Shape for Key mass, Image 6: torch.Size([])
# Image 7858, Key: mass
#   Scaling Factor: 0.0006
#   Scaled Predictions: [124.81119]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 7: (1,)
# Label Shape for Key protein, Image 7: torch.Size([])
# Image 7859, Key: protein
#   Scaling Factor: 0.0006
#   Scaled Predictions: [2.4004927]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 7: (1,)
# Label Shape for Key fat, Image 7: torch.Size([])
# Image 7859, Key: fat
#   Scaling Factor: 0.0006
#   Scaled Predictions: [4.540171]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 7: (1,)
# Label Shape for Key carbs, Image 7: torch.Size([])
# Image 7859, Key: carbs
#   Scaling Factor: 0.0006
#   Scaled Predictions: [13.616359]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 7: (1,)
# Label Shape for Key mass, Image 7: torch.Size([])
# Image 7859, Key: mass
#   Scaling Factor: 0.0006
#   Scaled Predictions: [111.45422]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 8: (1,)
# Label Shape for Key protein, Image 8: torch.Size([])
# Image 7860, Key: protein
#   Scaling Factor: 0.0007
#   Scaled Predictions: [3.2848837]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 8: (1,)
# Label Shape for Key fat, Image 8: torch.Size([])
# Image 7860, Key: fat
#   Scaling Factor: 0.0007
#   Scaled Predictions: [8.181541]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 8: (1,)
# Label Shape for Key carbs, Image 8: torch.Size([])
# Image 7860, Key: carbs
#   Scaling Factor: 0.0007
#   Scaled Predictions: [9.776879]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 8: (1,)
# Label Shape for Key mass, Image 8: torch.Size([])
# Image 7860, Key: mass
#   Scaling Factor: 0.0007
#   Scaled Predictions: [128.01584]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 9: (1,)
# Label Shape for Key protein, Image 9: torch.Size([])
# Image 7861, Key: protein
#   Scaling Factor: 0.0006
#   Scaled Predictions: [1.9862278]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 9: (1,)
# Label Shape for Key fat, Image 9: torch.Size([])
# Image 7861, Key: fat
#   Scaling Factor: 0.0006
#   Scaled Predictions: [3.1487923]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 9: (1,)
# Label Shape for Key carbs, Image 9: torch.Size([])
# Image 7861, Key: carbs
#   Scaling Factor: 0.0006
#   Scaled Predictions: [5.9603076]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 9: (1,)
# Label Shape for Key mass, Image 9: torch.Size([])
# Image 7861, Key: mass
#   Scaling Factor: 0.0006
#   Scaled Predictions: [73.44611]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 10: (1,)
# Label Shape for Key protein, Image 10: torch.Size([])
# Image 7862, Key: protein
#   Scaling Factor: 0.0002
#   Scaled Predictions: [4.086238]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 10: (1,)
# Label Shape for Key fat, Image 10: torch.Size([])
# Image 7862, Key: fat
#   Scaling Factor: 0.0002
#   Scaled Predictions: [1.7861537]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 10: (1,)
# Label Shape for Key carbs, Image 10: torch.Size([])
# Image 7862, Key: carbs
#   Scaling Factor: 0.0002
#   Scaled Predictions: [9.624933]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 10: (1,)
# Label Shape for Key mass, Image 10: torch.Size([])
# Image 7862, Key: mass
#   Scaling Factor: 0.0002
#   Scaled Predictions: [138.20316]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 11: (1,)
# Label Shape for Key protein, Image 11: torch.Size([])
# Image 7863, Key: protein
#   Scaling Factor: 0.0001
#   Scaled Predictions: [8.699702]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 11: (1,)
# Label Shape for Key fat, Image 11: torch.Size([])
# Image 7863, Key: fat
#   Scaling Factor: 0.0001
#   Scaled Predictions: [5.7136908]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 11: (1,)
# Label Shape for Key carbs, Image 11: torch.Size([])
# Image 7863, Key: carbs
#   Scaling Factor: 0.0001
#   Scaled Predictions: [10.181326]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 11: (1,)
# Label Shape for Key mass, Image 11: torch.Size([])
# Image 7863, Key: mass
#   Scaling Factor: 0.0001
#   Scaled Predictions: [141.7535]
#   True Values: 132.0
# Predictions Shape for Key protein, Image 12: (1,)
# Label Shape for Key protein, Image 12: torch.Size([])
# Image 7864, Key: protein
#   Scaling Factor: 0.0005
#   Scaled Predictions: [10.696783]
#   True Values: 10.097742242
# Predictions Shape for Key fat, Image 12: (1,)
# Label Shape for Key fat, Image 12: torch.Size([])
# Image 7864, Key: fat
#   Scaling Factor: 0.0005
#   Scaled Predictions: [4.753998]
#   True Values: 7.109348744
# Predictions Shape for Key carbs, Image 12: (1,)
# Label Shape for Key carbs, Image 12: torch.Size([])
# Image 7864, Key: carbs
#   Scaling Factor: 0.0005
#   Scaled Predictions: [6.8040032]
#   True Values: 8.609847605
# Predictions Shape for Key mass, Image 12: (1,)
# Label Shape for Key mass, Image 12: torch.Size([])
# Image 7864, Key: mass
#   Scaling Factor: 0.0005
#   Scaled Predictions: [115.597595]
#   True Values: 132.0
# Combined Values for Key: protein
#   Predictions - Min=-0.52, Max=149.24
#   True Values - Min=0.02, Max=105.58
# Combined Values for Key: fat
#   Predictions - Min=-1.11, Max=66.19
#   True Values - Min=0.00, Max=67.88
# Combined Values for Key: carbs
#   Predictions - Min=-1.98, Max=283.27
#   True Values - Min=0.00, Max=150.32
# Combined Values for Key: mass
#   Predictions - Min=-3.13, Max=566.13
#   True Values - Min=3.00, Max=608.00
# Protein MAE: 4.50
# Fat MAE: 3.23
# Carbs MAE: 4.61
# Mass MAE: 29.85
